# %% [markdown]
# # Constant Model
#
#
# [Acknowledgments Page](https://ds100.org/fa23/acks/)

# %%
pip install datascience
# Out:
# Requirement already satisfied: datascience in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (0.17.6)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (3.5.1)
# Requirement already satisfied: pandas in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.4.2)
# Requirement already satisfied: folium>=0.9.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.14.0)
# Requirement already satisfied: branca in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.6.0)
# Requirement already satisfied: numpy in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.21.5)
# Requirement already satisfied: setuptools in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (61.2.0)
# Requirement already satisfied: scipy in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.7.3)
# Requirement already satisfied: ipython in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (7.31.1)
# Requirement already satisfied: plotly in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (5.6.0)
# Requirement already satisfied: requests in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from folium>=0.9.1->datascience) (2.32.3)
# Requirement already satisfied: jinja2>=2.9 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from folium>=0.9.1->datascience) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (10.4.0)
# Requirement already satisfied: six>=1.5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->datascience) (1.16.0)
# Requirement already satisfied: pickleshare in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (4.8.0)
# Requirement already satisfied: pygments in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (2.11.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (5.14.3)
# Requirement already satisfied: jedi>=0.16 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.18.1)
# Requirement already satisfied: decorator in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: appnope in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (3.0.20)
# Requirement already satisfied: backcall in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->datascience) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->datascience) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from pandas->datascience) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from plotly->datascience) (8.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import itertools
from mpl_toolkits.mplot3d import Axes3D

import plotly.express as px
#from plotly.subplots import make_subplots
#import plotly.graph_objects as go
rng = np.random.default_rng()

# %%
# Big font helper
def adjust_fontsize(size=None):
    SMALL_SIZE = 8
    MEDIUM_SIZE = 10
    BIGGER_SIZE = 12
    if size != None:
        SMALL_SIZE = MEDIUM_SIZE = BIGGER_SIZE = size

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# <br/><br/>
#
# ---
#
# ## I). Boba Tea:  Two Constant Models, Fit to Different Losses
#
# ### Exploring MAE

# %%
boba = np.array([20, 21, 22, 29, 33])

# %% [markdown]
# Let's plot the $L_1$ loss for a **single** observation. We'll plot the $L_1$ loss for the first observation; since $y_1 = 20$, we'll be plotting
#
# $$
# \Large
# L_1(20, \theta_0) = |20 - \theta_0|
# $$

# %%
thetas = np.linspace(10, 30, 1000)
l1_loss_single_obvs = np.abs(boba[0] - thetas)

# %%
plt.style.use('default') # Revert style to default mpl
adjust_fontsize(size=16)
# %matplotlib inline

plt.plot(thetas, l1_loss_single_obvs,  'g--', );
plt.xlabel(r'$\theta_0$');
plt.ylabel(r'L1 Loss for $y = 20$');
# plt.savefig('l1_loss_single_obs.png', bbox_inches = 'tight');

# %%
def mae_constant(theta_0, data):
    return np.mean(np.array([np.abs(y_obs - theta_0) for y_obs in data]), axis=0)

thetas = np.linspace(10, 40, 1000)
l1_loss_thetas = mae_constant(thetas, boba)
plt.plot(thetas, l1_loss_thetas, color = 'green', lw=3);
plt.xlabel(r'$\theta_0$');
plt.ylabel(r'MAE across all data');
# plt.savefig('l1_loss_average.png', bbox_inches = 'tight');

# %% [markdown]
# ### Median Minimizes MAE for the Constant Model

# %%
# In case we're in a weird style state
sns.set_theme()
adjust_fontsize(size=16)
# %matplotlib inline

yobs = boba
thetahat = np.median(yobs)

fig = plt.figure(figsize=(8, 1.5))
sns.rugplot(yobs, height=0.25, lw=2) ;
plt.scatter([thetahat], [-.1], color='green', lw=4, label=r"$\hat{\theta}_0$");
plt.xlabel("Sales")
plt.legend()
plt.yticks([])
# plt.savefig('boba_rug.png', bbox_inches = 'tight');
plt.show()

# %% [markdown]
# ### MSE

# %%
def mse_constant(theta, data):
    return np.mean(np.array([(y_obs - theta) ** 2 for y_obs in data]), axis=0)

# %% [markdown]
# ### Two Constant Models, Fit to Different Losses

# %%
plt.style.use('default') # Revert style to default mpl
adjust_fontsize(size=16)
# %matplotlib inline

nplots = 2
def plot_losses(data, title=None, theta_range=(10, 40)):
    thetas = np.linspace(theta_range[0], theta_range[1], 1000)
    l2_loss_thetas = mse_constant(thetas, data)
    thetahat_mse = np.mean(data)

    l1_loss_thetas = mae_constant(thetas, data)
    thetahat_mae = np.median(data)

    fig, axs = plt.subplots(1, nplots, figsize=(5*2+0.5, 3.5))
    axs[0].plot(thetas, l2_loss_thetas, lw=3);
    axs[0].scatter([thetahat_mse], [mse_constant(thetahat_mse, data)], s=100)
    axs[0].annotate(r"$\hat{\theta}_0$ = " + f"{thetahat_mse:.1f}",
                    xy=(thetahat_mse, np.average(axs[0].get_ylim())),
                    size=20, ha='center', va='top',
                    bbox=dict(boxstyle='round', fc='w'))
    axs[0].set_xlabel(r'$\theta_0$');
    axs[0].set_ylabel(r'MSE');

    axs[1].plot(thetas, l1_loss_thetas, color = 'green', lw=3);
    axs[1].scatter([thetahat_mae], [mae_constant(thetahat_mae, data)], color='green', s=100)
    axs[1].annotate(r"$\hat{\theta}_0$ = " + f"{thetahat_mae:.1f}",
                    xy=(thetahat_mae, np.average(axs[1].get_ylim())),
                    size=20, ha='center', va='top',
                    bbox=dict(boxstyle='round', fc='w'))
    axs[1].set_xlabel(r'$\theta_0$');
    axs[1].set_ylabel(r'MAE');
    if title:
        fig.suptitle(title)
    fig.tight_layout()
    return fig

# %%
fig = plot_losses(boba)
plt.figure(fig)
# plt.savefig('loss_compare.png', bbox_inches = 'tight');
plt.show()

# %% [markdown]
# #### More loss comparison: Outliers

# %%
boba_outlier = np.array([20, 21, 22, 29, 33, 1033])
fig = plot_losses(boba_outlier, theta_range=[-10, 300])
plt.figure(fig)
# plt.savefig('loss_outlier.png', bbox_inches = 'tight');
plt.show()

# %% [markdown]
# #### Uniqueness under Different Loss Functions

# %%
boba_even = np.array([20, 21, 22, 29, 33, 35])
fig = plot_losses(boba_even)
plt.figure(fig)
#plt.savefig('loss_unique.png', bbox_inches = 'tight');
plt.show()

# %% [markdown]
# ### Supplemental Materials
# ### Additional Loss Functions:

# %% [markdown]
# Let's plot the $L_3$ loss for a **single** observation. We'll plot the $L_3$ loss for the first observation; since $y_1 = 20$, we'll be plotting
#
# $$
# \Large
# L_3(20, \theta_0) = |20 - \theta_0|^3
# $$

# %%
thetas = np.linspace(10, 30, 1000)
l3_loss_single_obvs = (np.abs(boba[0] - thetas))**3

# %%
plt.style.use('default') # Revert style to default mpl
adjust_fontsize(size=16)
# %matplotlib inline

plt.plot(thetas, l3_loss_single_obvs,  'g--', );
plt.xlabel(r'$\theta_0$');
plt.ylabel(r'L3 Loss for $y = 20$');

# %%
def l3_constant(theta_0, data):
    return np.mean(np.array([(np.abs(y_obs - theta_0))**3 for y_obs in data]), axis=0)

thetas = np.linspace(10, 40, 1000)
l3_loss_thetas = l3_constant(thetas, boba)
plt.plot(thetas, l3_loss_thetas, color = 'green', lw=3);
plt.xlabel(r'$\theta_0$');
plt.ylabel(r'Mean Ave L3 Loss across all data');
print(min(l3_loss_thetas))
# plt.savefig('l1_loss_average.png', bbox_inches = 'tight');
# Out:
# 152.8229296796729
